# %%
import numpy as np
import pandas as pd


from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class Library():
  def __init__(self, id):
    self.id = id
    self.books = []
    self.signup_days = 0
    self.signed = False
    self.books_per_day = 0
    self.start_shipping = 0 
    self.shipping_days = 0 
    self.shipping_in_progress = False

  def ship_books_library(self, libary_id):
    pass

# %%
class Book():
  def __init__(self):
    self.id = None
    self.value = None
    self.used = False

# %%
libList = []
libDict = {}



class Problem():
  def __init__(self):
    self.libraries = {}
    self.step = 0
    self.total_steps = 0
    self.total_books = 0
    self.total_libraries = 0
    self.scanned_ids = []
    self.signup_in_process = False
    self.library_in_signup_process = None
    self.book_df = pd.DataFrame()
    self.shipped_books = []



  def get_total_book_value(self):
    for library in libraries.values():
      for book in library.books:
        if book.id not in self.scanned_ids:
          self.libaries[library.id]['total_value'] += book.value
      self.total_book_values += book.value

  def ship_books(self):
    for library in self.libraries.values():
      if library.signup_days == 0:
        print('start shipping books from library {}'.format(library.id))
        for i in range(min(len(library.books), library.books_per_day)):
          print('shipping book id {}'.format(library.books[i]))
          libDict[library.id].append(library.books[i])
          self.shipped_books.append(library.books[i])
          del(library.books[i])
    #TODO set flag book shipped

  def get_lib_values(self):
      lib_score = {}

      for library in self.libraries.values():
          time_available = self.total_steps - self.step
          if not library.signed:
              time_available = time_available - library.signup_days

          howManyBooks = time_available * library.books_per_day

          lib_score[library.id] = self.sort_books().head(howManyBooks).sum()

      return lib_score

  def sort_books(self):
      return self.book_df.assign(f = self.book_df['bookScores'] * self.book_df['used']).sort_values('f', ascending=False).drop('f', axis=1)

  def get_next_lib(self):
    lib_scores = self.get_lib_values()
    dfLibs = pd.DataFrame.from_dict(lib_scores, orient='index')
    print('dfLibs')
    print(dfLibs)
    return dfLibs.sort_values(by=1, ascending=False).head(1)[1]

  def run(self):
    for i in range(0, self.total_libraries):
      libDict[i] = []

    library_id = self.get_next_lib()
    self.library_in_signup_process = library_id
    libList.append(library_id)
    print('library in signup process: {}'.format(library_id))
    while self.step <= self.total_steps:
      self.step += 1
      print('step: ', self.step)

      self.libraries[self.library_in_signup_process].signup_days -= 1
      if self.libraries[self.library_in_signup_process].signup_days == 0:
        library_id += 1
        if library_id < len(self.libraries):
          self.library_in_signup_process = library_id
          libList.append(library_id)
          print('start signing up library ', library_id)
      #shipping process
      problem.ship_books()
    return libDict, libList

# %%
problem.shipped_books
# Out:
# []

# %%
# read data
content = None

with open('drive/My Drive/Colab Notebooks/google_hashcode/2020/data/b_read_on.txt') as f:
    line1 = f.readline()
    line2 = f.readline()
    content = f.readlines()

# %%
# fist lines
parts = [int(s) for s in line1.split(' ')]

problem = Problem()

problem.total_books = parts[0]
problem.total_libraries = parts[1]
problem.total_steps = parts[2]

problem.book_df = pd.DataFrame({
    'bookScores': [int(s) for s in line2.split(' ')],
    'used': False
})

# %%
problem.book_df.head()
# Out:
#    bookScores   used
# 0         100  False
# 1         100  False
# 2         100  False
# 3         100  False
# 4         100  False

# %%
# %%

for i in range(0, problem.total_libraries * 2, 2):
    parts = [int(s) for s in content[i].split(' ')]

    lib =  Library(int(i/2))

    lib.total_books = parts[0]
    lib.signup_days = parts[1]
    lib.books_per_day = parts[2]
    lib.books = [int(s) for s in content[i + 1].split(' ')]
    problem.libraries[i/2] = lib

problem.libraries
# Out:
# {0.0: <__main__.Library at 0x7f5f2502c6a0>,
#  1.0: <__main__.Library at 0x7f5f2502c6d8>,
#  2.0: <__main__.Library at 0x7f5f2502c5c0>,
#  3.0: <__main__.Library at 0x7f5f2502c748>,
#  64.0: <__main__.Library at 0x7f5f2502f518>,
#  65.0: <__main__.Library at 0x7f5f2502f048>,
#  66.0: <__main__.Library at 0x7f5f2502f550>,
#  67.0: <__main__.Library at 0x7f5f2502f588>,
#  68.0: <__main__.Library at 0x7f5f2502f5f8>,
#  69.0: <__main__.Library at 0x7f5f2502f390>,
#  70.0: <__main__.Library at 0x7f5f2502f668>,
#  71.0: <__main__.Library at 0x7f5f2502f6a0>,
#  72.0: <__main__.Library at 0x7f5f2502f6d8>,
#  73.0: <__main__.Library at 0x7f5f2502f630>,
#  74.0: <__main__.Library at 0x7f5f2502f748>,
#  75.0: <__main__.Library at 0x7f5f2502f4a8>,
#  76.0: <__main__.Library at 0x7f5f2502f780>,
#  77.0: <__main__.Library at 0x7f5f2502f7b8>,
#  78.0: <__main__.Library at 0x7f5f2502f828>,
#  79.0: <__main__.Library at 0x7f5f2502f710>,
#  80.0: <__main__.Library at 0x7f5f2502f898>,
#  81.0: <__main__.Library at 0x7f5f2502f8d0>,
#  82.0: <__main__.Library at 0x7f5f2502f5c0>,
#  83.0: <__main__.Library at 0x7f5f2502f940>,
#  84.0: <__main__.Library at 0x7f5f2502f7f0>,
#  85.0: <__main__.Library at 0x7f5f2502f9b0>,
#  86.0: <__main__.Library at 0x7f5f2502f9e8>,
#  87.0: <__main__.Library at 0x7f5f2502fa20>,
#  88.0: <__main__.Library at 0x7f5f2502f978>,
#  89.0: <__main__.Library at 0x7f5f2502fa58>,
#  90.0: <__main__.Library at 0x7f5f2502fac8>,
#  91.0: <__main__.Library at 0x7f5f2502fb00>,
#  92.0: <__main__.Library at 0x7f5f2502f860>,
#  93.0: <__main__.Library at 0x7f5f2502fb70>,
#  94.0: <__main__.Library at 0x7f5f2502fba8>,
#  95.0: <__main__.Library at 0x7f5f2502fbe0>,
#  96.0: <__main__.Library at 0x7f5f28012828>,
#  97.0: <__main__.Library at 0x7f5f2a014898>,
#  98.0: <__main__.Library at 0x7f5f25022208>,
#  99.0: <__main__.Library at 0x7f5f25cd20b8>}

# %%
# get book value
problem.get_next_lib()
# Out:
#     bookScores  used
# 0      98000.0   0.0
# 1      98000.0   0.0
# 2      99400.0   0.0
# 3      98500.0   0.0
# 4      98500.0   0.0
# ..         ...   ...
# 95     98000.0   0.0
# 96     98000.0   0.0
# 97     98000.0   0.0
# 98     98200.0   0.0
# 99     98700.0   0.0
#
# [100 rows x 2 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-263-50eaca042e25> in <module>()
# ----> 1 problem.get_next_lib()
#       2
#
# <ipython-input-258-7d8848b1ce56> in get_next_lib(self)
#      58     dfLibs = pd.DataFrame.from_dict(lib_scores, orient='index')
#      59     print(dfLibs)
# ---> 60     return dfLibs.sort_values(by=1, ascending=False).head(1)[1]
#      61
#      62   def run(self):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    5006
#    5007             by = by[0]
# -> 5008             k = self._get_label_or_level_values(by, axis=axis)
#    5009
#    5010             if isinstance(ascending, (tuple, list)):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# KeyError: 1

# %%
libDict, libList = problem.run()
problem.shipped_books

# %%
' '.join(map(str, libDict[0]))

# %%
import os
os.getcwd()
# %ls

# %%
output = str(len(libList)) + '\n'

for i in libList:
  output = output + str(i) + ' ' + str(len(libDict[i])) + '\n'
  output = output + ' '.join(map(str, libDict[i])) + '\n'
#print(output)
with open("drive/My Drive/Colab Notebooks/google_hashcode/2020/data/b_sub.txt", "w") as text_file:
  text_file.write(output)
