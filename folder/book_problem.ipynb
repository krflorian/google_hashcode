# %%
import numpy as np
import pandas as pd


from google.colab import drive

drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
class Library():
  def __init__(self, id):
    self.id = id
    self.books = []
    self.signup_time = 0
    self.books_per_day = 0
    self.start_shipping = 0 
    self.shipping_days = 0 
    
  def ship_books_library(self, libary_id):
    pass

# %%
class Book():
  def __init__(self):
    self.id = None
    self.value = None
    self.used = False

# %%
class Problem():
  def __init__(self):
    self.libraries = {}
    self.step = 0
    self.total_steps = 0
    self.total_books = 0
    self.total_libraries = 0
    self.scanned_ids = []
    self.signup_in_process = False
    self.book_df = pd.DataFrame()

  def get_total_book_value(self):
    for library in libraries.values():
      for book in library.books:
        if book.id not in self.scanned_ids:
          self.libaries[library.id]['total_value'] += book.value
      self.total_book_values += book.value

  def signup_library(self, library_id):
    self.step += self.libraries[library_id].signup_time
    self.libraries[library_id].shipping_days = self.total_steps - self.step.copy()
  
  def run(self):
    while self.step <= self.total_steps:
      if not self.signup_in_process:
        self.libraries[library_id].signup_library()

# %%
# %ls
# Out:
# sample_data/

# %%
# read data

# %%
# %%

# %%
content = None

with open('drive/My Drive/Colab Notebooks/google_hashcode/2020/data/a_example.txt') as f:
    line1 = f.readline()
    line2 = f.readline()
    content = f.readlines()

# %%
# fist lines
parts = [int(s) for s in line1.split(' ')]

problem = Problem()

problem.total_books = parts[0]
problem.total_libraries = parts[1]
problem.total_steps = parts[2]

problem.book_df = pd.DataFrame({
    'bookScores': [int(s) for s in line2.split(' ')],
    'used': False
})

# %%
problem.book_df.head()
# Out:
#    bookScores   used
# 0           1  False
# 1           2  False
# 2           3  False
# 3           6  False
# 4           5  False

# %%
# %%

for i in range(0, problem.total_libraries * 2, 2):
    parts = [int(s) for s in content[i].split(' ')]

    lib =  Library(int(i/2))

    lib.total_books = parts[0]
    lib.signup_time = parts[1]
    lib.books_per_day = parts[2]
    lib.books = [int(s) for s in content[i + 1].split(' ')]
    problem.libraries[i/2] = lib

problem.libraries
# Out:
# {0.0: <__main__.Library at 0x7f5f27fdec50>,
#  1.0: <__main__.Library at 0x7f5f27fdebe0>}

# %%
# get book value
problem.libraries[0].__dict__
# Out:
# {'books': [0, 1, 2, 3, 4],
#  'books_per_day': 2,
#  'id': 0,
#  'shipping_days': 0,
#  'signup_time': 2,
#  'start_shipping': 0,
#  'total_books': 5}
